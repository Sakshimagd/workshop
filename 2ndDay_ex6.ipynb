# %%
# import necessary packages
import numpy as np

# create an array
data = np.array([50, 80, 90, 60, 75, 85])
normalizedData = (data-np.min(data))/(np.max(data)-np.min(data))

# normalized data using min max value
print(normalizedData)
# Out:
# [0.    0.75  1.    0.25  0.625 0.875]
